# %% [markdown]
# # **Mini Cuso de Python - Aula Extra**

# %% [markdown]
# ## Formatação de Dados

# %% [markdown]
# ### Formatação de String

# %% [markdown]
# ### Formatação de Data

# %% [markdown]
# ## Leitura e Escrita de Arquivos

# %% [markdown]
# #### Arquivo TXT

# %% [markdown]
# ### Arquivo CSV

# %% [markdown]
# #### Arquivo JSON

# %% [markdown]
# ## Analíse de Dados

# %% [markdown]
# ### Leitura de Dados com Requests

# %% [markdown]
# #### Tratamento de Dados com Pandas

# %% [markdown]
# #### Visualização de Dados com Matplotlib
