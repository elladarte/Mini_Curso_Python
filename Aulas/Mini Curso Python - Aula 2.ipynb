# %% [markdown]
# # **Mini Cuso de Python - Aula 2**

# %% [markdown]
# ## Estruturas

# %% [markdown]
# ### Estruturas Condicionais

# %% [markdown]
# #### Comandos ```if/else```

# %% [markdown]
# #### Extra: Comando ```with```

# %% [markdown]
# ### Estruturas de Repetição

# %% [markdown]
# #### Comandos ```for```

# %% [markdown]
# #### Comandos ```range```

# %% [markdown]
# #### Comandos ```while```

# %% [markdown]
# ### Estruturas de Controle de Fluxo

# %% [markdown]
# #### Comandos ```break```

# %% [markdown]
# #### Comandos ```continue```

# %% [markdown]
# #### Comandos ```pass```
