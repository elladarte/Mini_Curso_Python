# %% [markdown]
# # **Mini Cuso de Python - Aula 3**

# %% [markdown]
# ## Introdução a Programação Orientada a Objetos

# %% [markdown]
# ### Módulos e Pacotes

# %% [markdown]
# ### Métodos

# %% [markdown]
# ### Funções

# %% [markdown]
# #### Principais Funções bult-in

# %% [markdown]
# #### Expressões Lambda
