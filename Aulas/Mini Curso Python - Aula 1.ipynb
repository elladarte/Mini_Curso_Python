# %% [markdown]
# # **Mini Cuso de Python - Aula 1**

# %% [markdown]
# 1.  ## **Conhecendo a linguagem Python**

# %% [markdown]
# 1. ### Objetivos do Curso

# %% [markdown]
# 2. ### Linguagem de Programação

# %% [markdown]
# 3. ### História do Python

# %% [markdown]
# 4. ### Principais Características

# %% [markdown]
# 5. ### Vantagens e Desvantagens

# %% [markdown]
# 6. ### Principais Aplicações

# %% [markdown]
# 7. ### Obtenção e Instalação

# %% [markdown]
# 1. ## **Fundamentos**

# %% [markdown]
# 1. ### Variáveis

# %% [markdown]
# * #### Números

# %% [markdown]
# * #### Strings

# %% [markdown]
# 2. ### Operações Matemáticas

# %% [markdown]
# * #### Operadores

# %% [markdown]
# * #### Calculadora

# %% [markdown]
# 3. ### Entrada e Saida de Dados

# %% [markdown]
# 4. ### Estruturas de Dados

# %% [markdown]
# * #### Listas

# %% [markdown]
# * #### Tuplas

# %% [markdown]
# * #### Conjuntos

# %% [markdown]
# * #### Dicionarios
